# %%
#############################################################################################################
##### Notebook Explainability
##### Baseado em:
##  Dataset: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset
##
##############################################################################################################
## Objetivos:
##   Demosntrar os principais metodos de explainability

# %%
#!pip install xgboost
#!pip install dice-ml
# !pip install interpret
# Out:
# Collecting interpret
#   Downloading interpret-0.6.3-py3-none-any.whl.metadata (1.1 kB)
# Collecting interpret-core==0.6.3 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading interpret_core-0.6.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.11.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.24.3)
# Requirement already satisfied: scipy>=0.18.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.10.1)
# Requirement already satisfied: pandas>=0.19.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.18.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.3.0)
# Requirement already satisfied: joblib>=0.11 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.4.2)
# Requirement already satisfied: plotly>=3.8.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (5.22.0)
# Collecting shap>=0.28.5 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading shap-0.44.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: dill>=0.2.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.3.8)
# Requirement already satisfied: ipykernel>=4.10.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (6.28.0)
# Requirement already satisfied: ipython>=5.5.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (7.31.1)
# Collecting SALib>=1.3.3 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading salib-1.4.8-py3-none-any.whl.metadata (11 kB)
# Collecting aplr>=10.5.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading aplr-10.6.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting dash>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading dash-2.17.1-py3-none-any.whl.metadata (10 kB)
# Collecting dash-core-components>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-html-components>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-table>=4.1.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting dash-cytoscape>=0.1.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading dash_cytoscape-1.0.2.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 3.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Collecting gevent>=1.3.6 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading gevent-24.2.1-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.19.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2.32.2)
# Requirement already satisfied: psutil>=5.6.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (5.9.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/barbara/anaconda3/lib/python3.8/site-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.0.3)
# Requirement already satisfied: importlib-metadata in /home/barbara/anaconda3/lib/python3.8/site-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (4.11.0)
# Collecting retrying (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /home/barbara/anaconda3/lib/python3.8/site-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.6.0)
# Requirement already satisfied: setuptools in /home/barbara/anaconda3/lib/python3.8/site-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (69.5.1)
# Collecting zope.event (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading zope.event-5.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: zope.interface in /home/barbara/anaconda3/lib/python3.8/site-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (5.4.0)
# Requirement already satisfied: greenlet>=2.0.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.0.1)
# Requirement already satisfied: comm>=0.1.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.1.6)
# Requirement already satisfied: packaging in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (23.2)
# Requirement already satisfied: pyzmq>=24 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (5.14.3)
# Requirement already satisfied: jedi>=0.16 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.18.1)
# Requirement already satisfied: decorator in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (5.1.1)
# Requirement already satisfied: pickleshare in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.0.43)
# Requirement already satisfied: pygments in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2.15.1)
# Requirement already satisfied: backcall in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from pandas>=0.19.2->interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from pandas>=0.19.2->interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from plotly>=3.8.1->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (8.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2024.6.2)
# Requirement already satisfied: matplotlib>=3.2.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.7.2)
# Collecting multiprocess (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading multiprocess-0.70.16-py38-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.18.1->interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2.2.0)
# Requirement already satisfied: tqdm>=4.27.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (4.66.4)
# Collecting slicer==0.0.7 (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret)
#   Downloading slicer-0.0.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numba in /home/barbara/anaconda3/lib/python3.8/site-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.58.1)
# Requirement already satisfied: cloudpickle in /home/barbara/anaconda3/lib/python3.8/site-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2.2.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.6.2)
# Requirement already satisfied: zipp>=0.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from importlib-metadata->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.2.2->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/barbara/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.2.2->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.2.2->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.2.2->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.2.2->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (10.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.2.2->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.2.2->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (6.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /home/barbara/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.19.2->interpret-core==0.6.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from Werkzeug<3.1->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (2.1.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from numba->shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.3->interpret) (0.41.0)
# Downloading interpret-0.6.3-py3-none-any.whl (1.4 kB)
# Downloading interpret_core-0.6.3-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 4.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading aplr-10.6.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading dash-2.17.1-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 4.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading gevent-24.2.1-cp38-cp38-manylinux_2_28_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 4.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading salib-1.4.8-py3-none-any.whl (778 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.7/778.7 kB 4.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading shap-0.44.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (538 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.6/538.6 kB 5.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Downloading multiprocess-0.70.16-py38-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 4.7 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Building wheels for collected packages: dash-cytoscape
#   Building wheel for dash-cytoscape (setup.py) ... done
#   Created wheel for dash-cytoscape: filename=dash_cytoscape-1.0.2-py3-none-any.whl size=4010717 sha256=ecea5eaf6e699c863ab42b5cddb73bbfede0c9fdb82a2910745b55dbe7badebf
#   Stored in directory: /home/barbara/.cache/pip/wheels/ec/c2/8b/ccbebf62b6263f24a8be3e0367ae7aceeaaa2c7c73741a30fc
# Successfully built dash-cytoscape
# Installing collected packages: dash-table, dash-html-components, dash-core-components, zope.event, slicer, retrying, multiprocess, aplr, gevent, shap, SALib, interpret-core, dash, dash-cytoscape, interpret
# Successfully installed SALib-1.4.8 aplr-10.6.1 dash-2.17.1 dash-core-components-2.0.0 dash-cytoscape-1.0.2 dash-html-components-2.0.0 dash-table-5.0.0 gevent-24.2.1 interpret-0.6.3 interpret-core-0.6.3 multiprocess-0.70.16 retrying-1.3.4 shap-0.44.1 slicer-0.0.7 zope.event-5.0

# %%
import pandas as pd
import imblearn
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score
from interpret.blackbox import LimeTabular
from interpret import show

pd.set_option('display.max_columns', None)

import shap
import dice_ml

# %%
class DataLoader():
    def __init__(self):
        self.data = None

    def load_dataset(self, path="C:/Users/dealbuqc/Desktop/ontomqol/Datasets/stroke/healthcare-dataset-stroke-data.csv"):
        self.data = pd.read_csv(path)

    def preprocess_data(self):
        # One-hot encode para todas as colunas categoricas
        categorical_cols = ["gender",
                            "ever_married",
                            "work_type",
                            "Residence_type",
                            "smoking_status"]
        encoded = pd.get_dummies(self.data[categorical_cols], 
                                prefix=categorical_cols, dtype=float)

        # Atualiza dataset com novas colunas
        self.data = pd.concat([encoded, self.data], axis=1)
        self.data.drop(categorical_cols, axis=1, inplace=True)

        # Incluir valores que faltam na coluna BMI
        self.data.bmi = self.data.bmi.fillna(0)
        
        # Drop id - caracteristica nao eh relevante
        self.data.drop(["id"], axis=1, inplace=True)

    def get_data_split(self):
        X = self.data.iloc[:,:-1]
        y = self.data.iloc[:,-1]
        return train_test_split(X, y, test_size=0.20, random_state=2021)
    
    def oversample(self, X_train, y_train):
        oversample = RandomOverSampler(sampling_strategy='minority')
        # Converte para numpy e oversample
        x_np = X_train.to_numpy()
        y_np = y_train.to_numpy()
        x_np, y_np = oversample.fit_resample(x_np, y_np)
        # Convert de volta para pandas
        x_over = pd.DataFrame(x_np, columns=X_train.columns)
        y_over = pd.Series(y_np, name=y_train.name)
        return x_over, y_over

# %%
# Carregar dados
data_loader = DataLoader()
data_loader.load_dataset()
data_loader.preprocess_data()

# Separar em treinamento e avaliacao, fazendo o oversampling
X_train, X_test, y_train, y_test = data_loader.get_data_split()
X_train, y_train = data_loader.oversample(X_train, y_train)
print(X_train.shape)
print(X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5827/1340491986.py in <module>
#       1 # Carregar dados
#       2 data_loader = DataLoader()
# ----> 3 data_loader.load_dataset()
#       4 data_loader.preprocess_data()
#       5
#
# /tmp/ipykernel_5827/878148019.py in load_dataset(self, path)
#       4
#       5     def load_dataset(self, path="C:/Users/dealbuqc/Desktop/ontomqol/Datasets/stroke/healthcare-dataset-stroke-data.csv"):
# ----> 6         self.data = pd.read_csv(path)
#       7
#       8     def preprocess_data(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/dealbuqc/Desktop/ontomqol/Datasets/stroke/healthcare-dataset-stroke-data.csv'

# %%
# %% Treinar o modelo blackbox (pode ser qualquer um aqui)
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
print(f"Accuracy {accuracy_score(y_test, y_pred)}")

# %%
# Aplicar LIME

# Classificacao: predict_proba. Regressao: predict)
lime = LimeTabular(rf, 
                   X_train) # precisa do dataset para gerar as perturbacoes

# Retornar explanation
lime_local = lime.explain_local(X_test[-20:], 
                                y_test[-20:], 
                                name='LIME')
show(lime_local)

# %%
# Aplicar SHAP

import xgboost

model = xgboost.XGBClassifier(n_estimators=20)
model.fit(X_train, y_train)

explainer = shap.Explainer(model)
shap_values = explainer(X_train)
shap.plots.beeswarm(shap_values)

# %%
# Aplicar DiCE  (Diverse Counterfactual Explanations)

# Dataset
data_dice = dice_ml.Data(dataframe=data_loader.data, 
                         # Indicar quem sao as caracteristicas continuas (para perturbacao)
                         continuous_features=['age', 
                                              'avg_glucose_level',
                                              'bmi'], 
                         outcome_name='stroke')

# %%
# Modelo
rf_dice = dice_ml.Model(model=rf, 
                        backend="sklearn") # tf, torch, ...
explainer = dice_ml.Dice(data_dice, 
                         rf_dice, 
                         # Random sampling, genetic algorithm, kd-tree,... (Ver github.com/)
                         # Ver github.com/interpretml/DICE para outras opcoes incluindo para DL
                         method="random")

# %%
# %% Criar explanations
input_datapoint = X_test[0:1]
cf = explainer.generate_counterfactuals(input_datapoint, 
                                  total_CFs=3, 
                                  desired_class="opposite")

# Visualizar
cf.visualize_as_dataframe(show_only_changes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5827/4017034885.py in <module>
#       1 # %% Criar explanations
# ----> 2 input_datapoint = X_test[0:1]
#       3 cf = explainer.generate_counterfactuals(input_datapoint,
#       4                                   total_CFs=3,
#       5                                   desired_class="opposite")
#
# NameError: name 'X_test' is not defined

# %%
# %% Criar contrafatos condicionais
features_to_vary=['avg_glucose_level',
                  'bmi',
                  'smoking_status_smokes']
permitted_range={'avg_glucose_level':[80,250],
                'bmi':[18, 35]}

cf = explainer.generate_counterfactuals(input_datapoint, 
                                  total_CFs=3, 
                                  desired_class="opposite",
                                  permitted_range=permitted_range,
                                  features_to_vary=features_to_vary)
# Visualizacao
cf.visualize_as_dataframe(show_only_changes=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras.applications.vgg16 import VGG16
from innvestigate import create_analyzer

# Carregar os pesos do modelo pre-treinado VGG16
model = VGG16(weights='imagenet')

# %%
# Carregar um exemplo de imagem
img_path = 'C:/Users/dealbuqc/Desktop/ontomqol/Datasets/brain-mri/Testing/glioma_tumor/image(1).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
plt.imshow(img)

# %%
# Identificacao da imagem (classificao)
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])

# %%
## ESSE CODIGO VAI GERAR UM ERRO. TENTE ENTENDER O MOTIVO!

# Create an LRP analyzer
#analyzer = create_analyzer("lrp.z", model)
analyzer = create_analyzer("gradient", model)

# Aplicar o LRP a image
analysis = analyzer.analyze(x)

# Plotar o heatmap
plt.imshow(analysis.squeeze(), cmap='viridis')
plt.colorbar()
plt.show()

# Para uma implementacao correta (em pytorch), ver link abaixo:
# https://www.kaggle.com/code/gustavkeppler/layer-wise-relevance-propagation-lrp-on-vgg16

# %%
# Ver um demo em: 
### https://lrpserver.hhi.fraunhofer.de/image-classification
